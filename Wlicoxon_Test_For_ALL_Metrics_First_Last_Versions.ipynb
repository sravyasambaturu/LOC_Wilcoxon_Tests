# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyasambaturu/LOC_Wilcoxon_Tests/blob/main/Wlicoxon_Test_For_ALL_Metrics_First_Last_Versions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import io

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='MaxCyclomatic', header=0)

df
# Out:
#      <input type="file" id="files-a8745a49-18c0-47b9-8760-cc6c8edcc7a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8745a49-18c0-47b9-8760-cc6c8edcc7a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from scipy.stats import wilcoxon
import itertools
import pandas as pd # Added import for pandas


# Assuming 'df' is your DataFrame
# Convert the column names to strings if they are not already
df.columns = df.columns.astype(str)

# Your existing code
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])


df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])
df_results
# Out:
#      Version Combo  T-value  P-value                         Significance
# 0      7.11 vs 7.5      NaN      NaN  No significant difference detected.
# 1   7.11 vs 6.13.1      NaN      NaN  No significant difference detected.
# 2    7.11 vs 6.0.1      NaN      NaN  No significant difference detected.
# 3     7.11 vs 5.13      NaN      NaN  No significant difference detected.
# 4    7.5 vs 6.13.1      NaN      NaN  No significant difference detected.
# 5     7.5 vs 6.0.1      NaN      NaN  No significant difference detected.
# 6      7.5 vs 5.13      NaN      NaN  No significant difference detected.
# 7  6.13.1 vs 6.0.1      NaN      NaN  No significant difference detected.
# 8   6.13.1 vs 5.13      NaN      NaN  No significant difference detected.
# 9    6.0.1 vs 5.13      NaN      NaN  No significant difference detected.

# %%
from google.colab import files
import pandas as pd
import io

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='PercentLackOfCohesion', header=0)

df
# Out:
#      <input type="file" id="files-06f4ecad-22f3-4b03-b14b-1a1c25b7f306" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06f4ecad-22f3-4b03-b14b-1a1c25b7f306">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from scipy.stats import wilcoxon
import itertools
import pandas as pd # Added import for pandas


# Assuming 'df' is your DataFrame
# Convert the column names to strings if they are not already
df.columns = df.columns.astype(str)

# Your existing code
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])


df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])
df_results
# Out:
#      Version Combo  T-value  P-value                         Significance
# 0      7.11 vs 7.5      NaN      NaN  No significant difference detected.
# 1   7.11 vs 6.13.1      NaN      NaN  No significant difference detected.
# 2    7.11 vs 6.0.1      NaN      NaN  No significant difference detected.
# 3     7.11 vs 5.13      NaN      NaN  No significant difference detected.
# 4    7.5 vs 6.13.1      NaN      NaN  No significant difference detected.
# 5     7.5 vs 6.0.1      NaN      NaN  No significant difference detected.
# 6      7.5 vs 5.13      NaN      NaN  No significant difference detected.
# 7  6.13.1 vs 6.0.1      NaN      NaN  No significant difference detected.
# 8   6.13.1 vs 5.13      NaN      NaN  No significant difference detected.
# 9    6.0.1 vs 5.13      NaN      NaN  No significant difference detected.

# %%
from google.colab import files
import pandas as pd
import io

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='CountDeclInstanceVariable', header=0)

df
# Out:
#      <input type="file" id="files-3a68d361-e4f2-49d8-846f-691bca35aca0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a68d361-e4f2-49d8-846f-691bca35aca0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from scipy.stats import wilcoxon
import itertools
import pandas as pd # Added import for pandas


# Assuming 'df' is your DataFrame
# Convert the column names to strings if they are not already
df.columns = df.columns.astype(str)

# Your existing code
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])


df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])
df_results
# Out:
#      Version Combo  T-value  P-value                         Significance
# 0      7.11 vs 7.5      NaN      NaN  No significant difference detected.
# 1   7.11 vs 6.13.1      NaN      NaN  No significant difference detected.
# 2    7.11 vs 6.0.1      NaN      NaN  No significant difference detected.
# 3     7.11 vs 5.13      NaN      NaN  No significant difference detected.
# 4    7.5 vs 6.13.1      NaN      NaN  No significant difference detected.
# 5     7.5 vs 6.0.1      NaN      NaN  No significant difference detected.
# 6      7.5 vs 5.13      NaN      NaN  No significant difference detected.
# 7  6.13.1 vs 6.0.1      NaN      NaN  No significant difference detected.
# 8   6.13.1 vs 5.13      NaN      NaN  No significant difference detected.
# 9    6.0.1 vs 5.13      NaN      NaN  No significant difference detected.

# %%
from google.colab import files
import pandas as pd
import io
from scipy.stats import wilcoxon
import itertools

# Upload the file and read into a pandas DataFrame
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='CountDeclMethod', header=0)

# Display the original DataFrame
print("Original DataFrame:")  # Added for clarity
display(df)  # Using display for better formatting in Colab

# Perform Wilcoxon tests
df.columns = df.columns.astype(str)
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])

df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])

# Display the results DataFrame
print("\nWilcoxon Test Results:")  # Added for clarity
display(df_results)  # Using display for better formatting in Colab
# Out:
#      <input type="file" id="files-de600a7a-7e4d-4a6b-80b2-5947c9ede952" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de600a7a-7e4d-4a6b-80b2-5947c9ede952">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import io
from scipy.stats import wilcoxon
import itertools

# Upload the file and read into a pandas DataFrame
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='MaxInheritanceTree', header=0)

# Display the original DataFrame
print("Original DataFrame:")  # Added for clarity
display(df)  # Using display for better formatting in Colab

# Perform Wilcoxon tests
df.columns = df.columns.astype(str)
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])

df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])

# Display the results DataFrame
print("\nWilcoxon Test Results:")  # Added for clarity
display(df_results)  # Using display for better formatting in Colab
# Out:
#      <input type="file" id="files-fae4d69b-be33-468d-828d-5e93f7d24390" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fae4d69b-be33-468d-828d-5e93f7d24390">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import io
from scipy.stats import wilcoxon
import itertools

# Upload the file and read into a pandas DataFrame
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='CountDeclInstanceMethod', header=0)

# Display the original DataFrame
print("Original DataFrame:")  # Added for clarity
display(df)  # Using display for better formatting in Colab

# Perform Wilcoxon tests
df.columns = df.columns.astype(str)
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])

df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])

# Display the results DataFrame
print("\nWilcoxon Test Results:")  # Added for clarity
display(df_results)  # Using display for better formatting in Colab
# Out:
#      <input type="file" id="files-6f6b07ea-1494-425a-95d9-5ef8ac30b1e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f6b07ea-1494-425a-95d9-5ef8ac30b1e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import io
from scipy.stats import wilcoxon
import itertools

# Upload the file and read into a pandas DataFrame
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='CountDeclMethodAll', header=0)

# Display the original DataFrame
print("Original DataFrame:")  # Added for clarity
display(df)  # Using display for better formatting in Colab

# Perform Wilcoxon tests
df.columns = df.columns.astype(str)
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])

df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])

# Display the results DataFrame
print("\nWilcoxon Test Results:")  # Added for clarity
display(df_results)  # Using display for better formatting in Colab
# Out:
#      <input type="file" id="files-c3afda34-e476-4368-816a-1267e10d7834" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3afda34-e476-4368-816a-1267e10d7834">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import io
from scipy.stats import wilcoxon
import itertools

# Upload the file and read into a pandas DataFrame
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='CountClassDerived', header=0)

# Display the original DataFrame
print("Original DataFrame:")  # Added for clarity
display(df)  # Using display for better formatting in Colab

# Perform Wilcoxon tests
df.columns = df.columns.astype(str)
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])

df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])

# Display the results DataFrame
print("\nWilcoxon Test Results:")  # Added for clarity
display(df_results)  # Using display for better formatting in Colab
# Out:
#      <input type="file" id="files-3da9b396-823a-4cc7-a514-6208898c21c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3da9b396-823a-4cc7-a514-6208898c21c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import io
from scipy.stats import wilcoxon
import itertools

# Upload the file and read into a pandas DataFrame
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='CountClassCoupled', header=0)

# Display the original DataFrame
print("Original DataFrame:")  # Added for clarity
display(df)  # Using display for better formatting in Colab

# Perform Wilcoxon tests
df.columns = df.columns.astype(str)
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])

df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])

# Display the results DataFrame
print("\nWilcoxon Test Results:")  # Added for clarity
display(df_results)  # Using display for better formatting in Colab
# Out:
#      <input type="file" id="files-148b2a33-db46-4d79-acae-e872011a0afe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-148b2a33-db46-4d79-acae-e872011a0afe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import io
from scipy.stats import wilcoxon
import itertools

# Upload the file and read into a pandas DataFrame
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Set header=0 to use the first row as column names
  df = pd.read_excel(io.BytesIO(uploaded[fn]), sheet_name='CountClassBase', header=0)

# Display the original DataFrame
print("Original DataFrame:")  # Added for clarity
display(df)  # Using display for better formatting in Colab

# Perform Wilcoxon tests
df.columns = df.columns.astype(str)
columns_to_test = ['7.11', '7.5', '6.13.1', '6.0.1', '5.13']

results = []
for col1, col2 in itertools.combinations(columns_to_test, 2):
    statistic, p_value = wilcoxon(df[col1], df[col2])
    if p_value < 0.05:
        significance = "Significant difference detected."
    else:
        significance = "No significant difference detected."
    results.append([f"{col1} vs {col2}", statistic, p_value, significance])

df_results = pd.DataFrame(results, columns=["Version Combo", "T-value", "P-value", "Significance"])

# Display the results DataFrame
print("\nWilcoxon Test Results:")  # Added for clarity
display(df_results)  # Using display for better formatting in Colab
# Out:
#      <input type="file" id="files-863e82df-07fa-485d-98ec-7378fa125cac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-863e82df-07fa-485d-98ec-7378fa125cac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
